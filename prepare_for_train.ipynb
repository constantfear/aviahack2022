# %%
import pandas as pd
import numpy as np

# %%
data_export = pd.read_excel('Data\\5.Расходные операции_янв-дек2021.xlsx')

# %%
data_import = pd.read_excel('Data\\6.Приходные операции_2020-2021.xlsx')

# %%
data_export
# Out:
#        Дата операции       Тип операции Источник операции     Код позиции  \
# 0         2021-03-26  Списание в монтаж  Зак. на перемещ.  132.019.000078
# 1         2021-04-20  Списание в монтаж  Зак. на перемещ.  132.019.000080
# 2         2021-02-11  Списание в монтаж  Зак. на перемещ.  144.020.000270
# 3         2021-02-11  Списание в монтаж  Зак. на перемещ.  144.020.000270
# 4         2021-03-17  Списание в монтаж  Зак. на перемещ.  144.020.000270
# ...              ...                ...               ...             ...
# 192409    2020-12-25  Списание в монтаж  Зак. на перемещ.  181.022.000001
# 192410    2020-11-19  Списание в монтаж  Зак. на перемещ.  144.020.001170
# 192411    2020-11-27  Списание в монтаж  Зак. на перемещ.  315.346.000583
# 192412    2020-12-21  Прям.отгр.вн.зак.      Внутр. заказ  173.346.003002
# 192413    2020-12-22  Списание в монтаж  Зак. на перемещ.  173.346.003001
#
#                                          Описание позиции  \
# ...

# %%
data_import
# Out:
# 1             Дата операции Тип операции по приходным операциям  \
# 2       2020-01-09 00:00:00                      Поступление ЗП
# 3       2020-01-09 00:00:00                      Поступление ЗП
# 4       2020-01-09 00:00:00                      Поступление ЗП
# 5       2020-01-09 00:00:00                      Поступление ЗП
# 6       2020-01-09 00:00:00                      Поступление ЗП
# ...                     ...                                 ...
# 103110  2021-12-23 00:00:00         Поступление от демонтажа ОС
# 103111  2021-12-30 00:00:00         Поступление от демонтажа ОС
# 103112  2021-12-30 00:00:00         Поступление от демонтажа ОС
# 103113  2021-12-30 00:00:00         Поступление от демонтажа ОС
# 103114  2021-12-30 00:00:00         Поступление от демонтажа ОС
#
# 1          Код позиции                                   Описание позиции  \
# 2       145.346.000338          Антенна MOBI MB3F2600-65-1717.5DDE-DFM-IN
# ...

# %%
data_import.columns = data_import.iloc[1]

# %%
data_import = data_import.iloc[2:]

# %%
data_import.sort_values(by=['Дата операции'])
# Out:
# 1             Дата операции Тип операции по приходным операциям  \
# 2       2020-01-09 00:00:00                      Поступление ЗП
# 21      2020-01-09 00:00:00                    Поступ.в/п.вн.з.
# 22      2020-01-09 00:00:00                    Поступ.в/п.вн.з.
# 23      2020-01-09 00:00:00                    Поступ.в/п.вн.з.
# 24      2020-01-09 00:00:00                    Поступ.в/п.вн.з.
# ...                     ...                                 ...
# 102833  2021-12-30 00:00:00                  Возврат из монтажа
# 102832  2021-12-30 00:00:00                  Возврат из монтажа
# 102831  2021-12-30 00:00:00                  Возврат из монтажа
# 102841  2021-12-30 00:00:00                  Возврат из монтажа
# 103114  2021-12-30 00:00:00         Поступление от демонтажа ОС
#
# 1          Код позиции                                   Описание позиции  \
# 2       145.346.000338          Антенна MOBI MB3F2600-65-1717.5DDE-DFM-IN
# ...

# %%
data_import.columns[11]
# Out:
# nan

# %%
data_import = data_import.drop(['Тип операции по приходным операциям','Описание позиции', 'Описание Организации', 'ЕИ', 'Количество ', 'Объем за единицу', 'ЕИ объема', data_import.columns[11]], axis = 1)

# %%
data_import_SZ = data_import[data_import['Код Организации']=='304']
data_import_U = data_import[data_import['Код Организации']=='702']
data_import_M = data_import.loc[(data_import['Код Организации']=='101') | (data_import['Код Организации']=='К04') | (data_import['Код Организации']=='К05') | (data_import['Код Организации']=='107')]

# %%
data_import_SZ = data_import_SZ.drop(['Код Организации', 'Код позиции'], axis=1)

# %%
data_import_SZ = data_import_SZ.groupby(['Дата операции']).sum()

# %%
import datetime as DT

# %%
data_import_SZ
# Out:
# 1              Общий объем
# Дата операции
# 2020-01-09        0.101329
# 2020-01-14        0.045000
# 2020-01-20       75.852000
# 2020-01-21      166.275273
# 2020-01-22       48.003058
# ...                    ...
# 2021-12-26        1.551011
# 2021-12-27      141.442075
# 2021-12-28        6.428597
# 2021-12-29       23.366661
# 2021-12-30       34.692770
#
# [497 rows x 1 columns]

# %%
ind = pd.date_range(DT.datetime(2020, 1, 1),DT.datetime(2021, 12, 31)).strftime('%Y-%m-%d').tolist()

# %%
# Out:
# ['2020-01-01',
#  '2020-01-02',
#  '2020-01-03',
#  '2020-01-04',
#  '2020-01-05',
#  '2020-01-06',
#  '2020-01-07',
#  '2020-01-08',
#  '2020-01-09',
#  '2020-01-10',
#  '2020-01-11',
#  '2020-01-12',
#  '2020-01-13',
#  '2020-01-14',
#  '2020-01-15',
#  '2020-01-16',
#  '2020-01-17',
#  '2020-01-18',
#  '2020-01-19',
#  '2020-01-20',
#  '2020-01-21',
#  '2020-01-22',
#  '2020-01-23',
#  '2020-01-24',
#  '2020-01-25',
#  '2020-01-26',
#  '2020-01-27',
#  '2020-01-28',
#  '2020-01-29',
#  '2020-01-30',
#  '2020-01-31',
#  '2020-02-01',
#  '2020-02-02',
#  '2020-02-03',
#  '2020-02-04',
#  '2020-02-05',
#  '2020-02-06',
#  '2020-02-07',
#  '2020-02-08',
#  '2020-02-09',
#  '2020-02-10',
#  '2020-02-11',
#  '2020-02-12',
#  '2020-02-13',
#  '2020-02-14',
#  '2020-02-15',
#  '2020-02-16',
#  '2020-02-17',
#  '2020-02-18',
#  '2020-02-19',
#  '2020-02-20',
#  '2020-02-21',
#  '2020-02-22',
#  '2020-02-23',
#  '2020-02-24',
#  '2020-02-25',
#  '2020-02-26',
#  '2020-02-27',
# ...

# %%
df_import_SZ = pd.DataFrame(ind)

# %%
data_import_SZ = pd.DataFrame(data_import_SZ)

# %%
data_import_SZ['1']
# Out:
# Дата операции
# 2020-01-09      0.101329
# 2020-01-14      0.045000
# 2020-01-20     75.852000
# 2020-01-21    166.275273
# 2020-01-22     48.003058
#                  ...
# 2021-12-26      1.551011
# 2021-12-27    141.442075
# 2021-12-28      6.428597
# 2021-12-29     23.366661
# 2021-12-30     34.692770
# Name: 1, Length: 497, dtype: float64

# %%
df_import_SZ.merge(data_import_SZ['1'], on=)
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# d:\Projects\aviahack2022\prepare_for_train.ipynb Ячейка 20 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/Projects/aviahack2022/prepare_for_train.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> df_import_SZ.merge(data_import_SZ)
#
# File d:\Anaconda\lib\site-packages\pandas\core\frame.py:9345, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#    9326 @Substitution("")
#    9327 @Appender(_merge_doc, indents=2)
#    9328 def merge(
#    (...)
#    9341     validate: str | None = None,
#    9342 ) -> DataFrame:
#    9343     from pandas.core.reshape.merge import merge
# -> 9345     return merge(
#    9346         self,
#    9347         right,
#    9348         how=how,
#    9349         on=on,
#    9350         left_on=left_on,
# ...

# %%
df_import_SZ.merge()

# %%
data_import_SZ.plot()
# Out:
# <AxesSubplot:xlabel='Дата операции'>
